# %% [markdown]
# # Model selection

# %% [markdown]
# ## Imports

# %%
import os
import sys
sys.path.append("..")

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import src.Cleaning_pipeline as fn
from scipy import stats
import math




from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, Normalizer
from sklearn.pipeline import make_pipeline
from sklearn.compose import TransformedTargetRegressor

from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet, BayesianRidge
from sklearn.metrics import mean_squared_error, r2_score

from sklearn.neighbors import KNeighborsRegressor, RadiusNeighborsRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor

# %%
train = pd.read_csv('../INPUT/diamonds_train.csv') 
test = pd.read_csv('../INPUT/diamonds_test.csv')

# %% [markdown]
# ## Data Engineering

# %%
train_clean = fn.clean_data(train, test_data=False)
test_clean = fn.clean_data(test, test_data=True)

# %%
X_clean = train_clean.drop(['price'], axis= 1)
y = train_clean.price

# %% [markdown]
# ### Model testing

# %%
X_train, X_test, y_train, y_test = train_test_split(X_clean, y, test_size=0.2, random_state = 0)

# %% [markdown]
# **Regressors of classification models:**

# %%
models = {
    "Kneighbors" : KNeighborsRegressor(n_neighbors=10, weights='distance', algorithm='auto', leaf_size=30,),

    #"RadiusKneighbors" : RadiusNeighborsRegressor(radius=1.0, weights='distance', algorithm='auto'),
    #"GradDescReg" : TransformedTargetRegressor(SGDRegressor(loss='squared_loss', penalty='l2', alpha=0.0001, l1_ratio=0.15, fit_intercept=True, random_state=0),
                                               #func=np.log1p,
                                                #inverse_func=np.expm1),
    "RandForest" : RandomForestRegressor(n_estimators=700, criterion='mse', max_depth=None, min_samples_split=5, min_samples_leaf=2, random_state=0),

    "DecTreeReg": DecisionTreeRegressor(criterion='mse', splitter='best', max_depth=None, min_samples_split=2, min_samples_leaf=1, random_state=0)
}

for modelName, model in models.items():
    print(f"Training model: {modelName}")
    model.fit(X_train, y_train)
print('Training done')
# Out:
# Training model: Kneighbors
# Training model: RandForest
# Training model: DecTreeReg
# Training done

# %%
for name, model in models.items():
    print(f"---------[{name}]---------:")
    y_pred = model.predict(X_test)
    print("MSE = ",round(mean_squared_error(y_test,y_pred),5))
    print("RMSE = ",np.sqrt(mean_squared_error(y_test,y_pred)))
    print(r2_score(y_test, y_pred))
# Out:
# ---------[Kneighbors]---------:
# MSE =  368110.0155
# RMSE =  606.7207063407085
# 0.9769077984437536
# ---------[RandForest]---------:
# MSE =  299902.91396
# RMSE =  547.6339233076549
# 0.9811865522676602
# ---------[DecTreeReg]---------:
# MSE =  544468.15876
# RMSE =  737.8808567483858
# 0.9658445357815645

# %% [markdown]
# **Strictly regression models (with transformed target):**

# %%
models = {
    "LinearRegression" : TransformedTargetRegressor(LinearRegression(),
                                            func=np.log1p,
                                            inverse_func=np.expm1),
    "Ridge" : TransformedTargetRegressor(Ridge(alpha=1, tol=0.001, solver='auto', random_state=0),
                                         func=np.log1p,
                                            inverse_func=np.expm1),
    "Lasso" : TransformedTargetRegressor(Lasso(alpha=1, max_iter=1000, tol=0.0001),
                                         func=np.log1p,
                                            inverse_func=np.expm1),
    "ElasticNet" : TransformedTargetRegressor(ElasticNet(alpha=1.0, l1_ratio=0.5, fit_intercept=True, tol=0.0001, random_state=0),
                                              func=np.log1p,
                                            inverse_func=np.expm1),
    "BayesianRidge": TransformedTargetRegressor(BayesianRidge(n_iter=300, tol=0.001, alpha_1=1e-06, alpha_2=1e-06, lambda_1=1e-06, lambda_2=1e-06),
                                                func=np.log1p,
                                            inverse_func=np.expm1)
}

for modelName, model in models.items():
    print(f"Training model: {modelName}")
    model.fit(X_train, y_train)
# Out:
# Training model: LinearRegression
# Training model: Ridge
# Training model: Lasso
# Training model: ElasticNet
# Training model: BayesianRidge

# %%
for name, model in models.items():
    print(f"---------[{name}]---------:")
    y_pred = model.predict(X_test)

    print("MSE = ",round(mean_squared_error(y_test,y_pred),5))
    print("RMSE = ",np.sqrt(mean_squared_error(y_test,y_pred)))
    print(r2_score(y_test, y_pred))
# Out:
# ---------[LinearRegression]---------:
# MSE =  3035322.39142
# RMSE =  1742.217664765384
# 0.8095887818885439
# ---------[Ridge]---------:
# MSE =  3033338.02299
# RMSE =  1741.6480766753332
# 0.8097132648797751
# ---------[Lasso]---------:
# MSE =  18174480.5053
# RMSE =  4263.153821445274
# -0.14011776190210545
# ---------[ElasticNet]---------:
# MSE =  10460828.00923
# RMSE =  3234.320331883458
# 0.34377349525609324
# ---------[BayesianRidge]---------:
# MSE =  3034226.89004
# RMSE =  1741.9032378516704
# 0.8096575046552779

# %% [markdown]
# ### Model blending

# %% [markdown]
# Re-split the train data in train and validation data

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state = 0)

# %% [markdown]
# Fit two models:

# %%
model1 = RandomForestRegressor(n_estimators=700, criterion='mse', max_depth=None, min_samples_split=5, min_samples_leaf=4, random_state=0)
model1.fit(X_train, y_train)
val_pred1=model1.predict(X_val)
test_pred1=model1.predict(X_test)
val_pred1=pd.DataFrame(val_pred1)
test_pred1=pd.DataFrame(test_pred1)

model2 = GradientBoostingRegressor()
model2.fit(X_train,y_train)
val_pred2=model2.predict(X_val)
test_pred2=model2.predict(X_test)
val_pred2=pd.DataFrame(val_pred2)
test_pred2=pd.DataFrame(test_pred2)

# %% [markdown]
# Use the predictions as features for other model:

# %%
df_val=pd.concat([X_val.reset_index(), val_pred1,val_pred2],axis=1)
df_test=pd.concat([X_test.reset_index(), test_pred1,test_pred2],axis=1)

# %%
model = RandomForestRegressor(n_estimators=700, criterion='mse', max_depth=None, min_samples_split=5, min_samples_leaf=4, random_state=0)
model.fit(df_val,y_val)
model.score(df_test,y_test)
# Out:
# 0.9803899733255049

# %%
y_pred = model.predict(df_test)
print("MSE = ",round(mean_squared_error(y_test,y_pred),5))
print("RMSE = ",np.sqrt(mean_squared_error(y_test,y_pred)))
print(r2_score(y_test, y_pred))
# Out:
# MSE =  312601.08334
# RMSE =  559.1073987513707
# 0.9803899733255049

# %% [markdown]
# **Working on the best model**

# %%
parameters = {
    'n_estimators':[100, 200, 300,700,1000],
    'criterion':['mse'],
    'max_features':["auto"],
    'min_samples_split':[2,3,4,5,6,7],
    'min_samples_leaf':[2,3,4,5,6,7]
}
rndfor = RandomForestRegressor()
rndfor_select = GridSearchCV(rndfor, parameters, verbose=4)
rndfor_select.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 180 candidates, totalling 900 fits
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100, score=0.980, total=   4.8s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    4.8s remaining:    0.0s
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100, score=0.977, total=   4.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    9.5s remaining:    0.0s
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100, score=0.981, total=   4.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:   14.1s remaining:    0.0s
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100, score=0.981, total=   4.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=100, score=0.980, total=   4.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200, score=0.979, total=   9.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200, score=0.977, total=   9.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200, score=0.981, total=   9.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200, score=0.981, total=   9.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=200, score=0.980, total=   9.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300, score=0.979, total=  14.0s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300, score=0.977, total=  13.9s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300, score=0.981, total=  13.9s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300, score=0.981, total=  13.9s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=300, score=0.980, total=  14.0s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=700, score=0.980, total=  32.8s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=700, score=0.977, total=  32.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=700, score=0.981, total=  32.4s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=700, score=0.981, total=  32.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=700, score=0.980, total=  32.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000, score=0.980, total=  46.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000, score=0.977, total=  46.4s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000, score=0.981, total=  46.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000, score=0.981, total=  46.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=2, n_estimators=1000, score=0.980, total=  46.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=100, score=0.979, total=   4.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=100, score=0.977, total=   4.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=100, score=0.981, total=   4.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=100, score=0.981, total=   4.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=100, score=0.980, total=   4.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=200, score=0.980, total=   9.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=200, score=0.977, total=   9.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=200, score=0.981, total=   9.2s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=200, score=0.981, total=   9.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=200, score=0.980, total=   9.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=300, score=0.980, total=  13.9s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=300, score=0.977, total=  14.0s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=300, score=0.981, total=  13.9s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=300, score=0.981, total=  14.0s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=300, score=0.980, total=  14.0s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=700, score=0.980, total=  32.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=700, score=0.977, total=  32.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=700, score=0.981, total=  32.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=700, score=0.981, total=  32.4s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=700, score=0.980, total=  32.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=1000, score=0.980, total=  46.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=1000, score=0.977, total=  46.2s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=1000, score=0.981, total=  46.2s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=1000, score=0.981, total=  46.4s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=3, n_estimators=1000, score=0.980, total=  46.4s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=100, score=0.979, total=   4.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=100, score=0.977, total=   4.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=100, score=0.981, total=   4.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=100, score=0.981, total=   4.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=100, score=0.980, total=   4.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=200, score=0.979, total=   9.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=200, score=0.977, total=   9.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=200, score=0.981, total=   9.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=200, score=0.981, total=   9.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=200, score=0.980, total=   9.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=300, score=0.980, total=  13.9s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=300, score=0.977, total=  13.9s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=300, score=0.981, total=  13.9s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=300, score=0.981, total=  13.9s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=300, score=0.980, total=  13.9s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=700, score=0.980, total=  32.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=700, score=0.977, total=  32.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=700, score=0.981, total=  32.4s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=700, score=0.981, total=  32.4s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=700, score=0.980, total=  32.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=1000, score=0.980, total=  46.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=1000, score=0.977, total=  46.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=1000, score=0.981, total=  46.2s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=1000, score=0.981, total=  46.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=4, n_estimators=1000, score=0.980, total=  46.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100, score=0.980, total=   4.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100, score=0.977, total=   4.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100, score=0.981, total=   4.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100, score=0.981, total=   4.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=100, score=0.980, total=   4.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200, score=0.980, total=   9.0s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200, score=0.977, total=   9.0s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200, score=0.981, total=   9.0s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200, score=0.981, total=   9.0s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=200, score=0.980, total=   9.0s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300, score=0.980, total=  13.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300, score=0.977, total=  13.4s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300, score=0.981, total=  13.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300, score=0.981, total=  13.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=300, score=0.980, total=  13.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=700, score=0.980, total=  31.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=700, score=0.977, total=  31.4s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=700, score=0.981, total=  31.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=700, score=0.981, total=  31.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=700, score=0.980, total=  31.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1000, score=0.980, total=  45.0s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1000, score=0.977, total=  44.9s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1000, score=0.981, total=  44.9s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1000, score=0.981, total=  45.0s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=5, n_estimators=1000, score=0.980, total=  45.0s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100, score=0.980, total=   4.4s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100, score=0.978, total=   4.4s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100, score=0.981, total=   4.4s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100, score=0.981, total=   4.4s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=100, score=0.980, total=   4.4s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200, score=0.979, total=   8.8s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200, score=0.977, total=   8.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200, score=0.981, total=   8.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200, score=0.981, total=   8.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=200, score=0.980, total=   8.9s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=300, score=0.980, total=  13.2s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=300, score=0.977, total=  13.1s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=300, score=0.981, total=  13.1s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=300, score=0.981, total=  13.2s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=300, score=0.980, total=  13.2s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=700, score=0.980, total=  30.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=700, score=0.977, total=  30.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=700, score=0.981, total=  30.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=700, score=0.981, total=  30.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=700, score=0.981, total=  30.8s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=1000, score=0.980, total=  44.0s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=1000, score=0.977, total=  43.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=1000, score=0.981, total=  43.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=1000, score=0.981, total=  43.9s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=6, n_estimators=1000, score=0.980, total=  43.8s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100, score=0.979, total=   4.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100, score=0.977, total=   4.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100, score=0.981, total=   4.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100, score=0.981, total=   4.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=100, score=0.981, total=   4.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=200, score=0.980, total=   8.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=200, score=0.977, total=   8.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=200, score=0.981, total=   8.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=200, score=0.981, total=   8.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=200, score=0.980, total=   8.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=300, score=0.980, total=  12.8s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=300, score=0.977, total=  12.8s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=300, score=0.981, total=  12.8s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=300, score=0.981, total=  12.8s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=300, score=0.980, total=  12.9s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=700, score=0.980, total=  30.1s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=700, score=0.977, total=  29.8s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=700, score=0.981, total=  29.9s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=700, score=0.981, total=  29.9s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=700, score=0.980, total=  30.0s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=1000, score=0.980, total=  42.9s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=1000, score=0.977, total=  42.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=1000, score=0.981, total=  42.8s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=1000, score=0.981, total=  42.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=2, min_samples_split=7, n_estimators=1000, score=0.980, total=  43.0s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=100, score=0.980, total=   4.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=100, score=0.977, total=   4.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=100, score=0.981, total=   4.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=100, score=0.981, total=   4.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=100, score=0.980, total=   4.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=200, score=0.980, total=   8.8s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=200, score=0.977, total=   8.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=200, score=0.981, total=   8.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=200, score=0.981, total=   8.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=200, score=0.980, total=   8.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=300, score=0.980, total=  13.0s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=300, score=0.977, total=  13.0s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=300, score=0.981, total=  12.8s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=300, score=0.981, total=  12.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=300, score=0.980, total=  12.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=700, score=0.980, total=  29.9s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=700, score=0.977, total=  29.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=700, score=0.981, total=  29.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=700, score=0.981, total=  29.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=700, score=0.980, total=  29.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=1000, score=0.980, total=  42.4s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=1000, score=0.977, total=  42.1s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=1000, score=0.981, total=  42.4s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=1000, score=0.981, total=  42.2s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=2, n_estimators=1000, score=0.980, total=  42.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=100, score=0.980, total=   4.2s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=100, score=0.977, total=   4.2s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=100, score=0.981, total=   4.2s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=100, score=0.981, total=   4.4s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=100, score=0.980, total=   4.2s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=200, score=0.980, total=   8.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=200, score=0.977, total=   8.4s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=200, score=0.981, total=   8.4s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=200, score=0.981, total=   8.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=200, score=0.980, total=   8.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=300, score=0.979, total=  12.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=300, score=0.977, total=  12.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=300, score=0.981, total=  12.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=300, score=0.981, total=  12.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=300, score=0.980, total=  12.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=700, score=0.980, total=  29.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=700, score=0.977, total=  29.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=700, score=0.981, total=  29.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=700, score=0.981, total=  29.4s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=700, score=0.980, total=  29.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=1000, score=0.980, total=  42.4s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=1000, score=0.977, total=  42.4s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=1000, score=0.981, total=  42.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=1000, score=0.981, total=  42.2s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=3, n_estimators=1000, score=0.980, total=  42.4s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=100, score=0.979, total=   4.2s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=100, score=0.977, total=   4.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=100, score=0.981, total=   4.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=100, score=0.981, total=   4.2s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=100, score=0.980, total=   4.2s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=200, score=0.980, total=   8.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=200, score=0.977, total=   8.4s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=200, score=0.981, total=   8.4s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=200, score=0.981, total=   8.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=200, score=0.980, total=   8.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=300, score=0.980, total=  12.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=3, min_samples_split=4, n_estimators=300, score=0.977, total=  12.6s
# ...
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=300, score=0.979, total=  10.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=300, score=0.976, total=  10.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=300, score=0.980, total=  10.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=300, score=0.980, total=  10.8s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=300, score=0.979, total=  10.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=700, score=0.979, total=  25.1s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=700, score=0.976, total=  24.8s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=700, score=0.980, total=  25.0s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=700, score=0.980, total=  24.9s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=700, score=0.979, total=  25.1s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=1000, score=0.979, total=  35.9s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=1000, score=0.976, total=  35.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=1000, score=0.980, total=  35.8s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=1000, score=0.980, total=  35.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=5, n_estimators=1000, score=0.979, total=  35.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=100, score=0.978, total=   3.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=100, score=0.976, total=   3.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=100, score=0.980, total=   3.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=100, score=0.980, total=   3.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=100, score=0.979, total=   3.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=200, score=0.979, total=   7.1s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=200, score=0.976, total=   7.1s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=200, score=0.980, total=   7.1s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=200, score=0.980, total=   7.2s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=200, score=0.979, total=   7.1s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=300, score=0.979, total=  10.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=300, score=0.976, total=  10.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=300, score=0.980, total=  10.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=300, score=0.980, total=  10.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=300, score=0.979, total=  10.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=700, score=0.979, total=  25.0s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=700, score=0.976, total=  24.8s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=700, score=0.980, total=  24.9s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=700, score=0.980, total=  24.9s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=700, score=0.979, total=  25.0s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=1000, score=0.979, total=  35.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=1000, score=0.976, total=  35.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=1000, score=0.980, total=  35.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=1000, score=0.980, total=  35.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=6, n_estimators=1000, score=0.979, total=  35.8s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=100, score=0.979, total=   3.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=100, score=0.976, total=   3.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=100, score=0.980, total=   3.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=100, score=0.980, total=   3.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=100
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=100, score=0.979, total=   3.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=200, score=0.979, total=   7.1s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=200, score=0.976, total=   7.1s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=200, score=0.979, total=   7.1s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=200, score=0.980, total=   7.1s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=200
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=200, score=0.979, total=   7.2s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=300, score=0.978, total=  10.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=300, score=0.976, total=  10.6s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=300, score=0.980, total=  10.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=300, score=0.980, total=  10.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=300
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=300, score=0.979, total=  10.8s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=700, score=0.979, total=  25.0s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=700, score=0.976, total=  24.9s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=700, score=0.980, total=  24.9s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=700, score=0.980, total=  24.9s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=700
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=700, score=0.979, total=  25.3s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=1000, score=0.979, total=  35.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=1000, score=0.976, total=  35.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=1000, score=0.980, total=  35.5s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=1000, score=0.980, total=  35.7s
# [CV] criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=1000
# [CV]  criterion=mse, max_features=auto, min_samples_leaf=7, min_samples_split=7, n_estimators=1000, score=0.979, total=  35.7s
# [Parallel(n_jobs=1)]: Done 900 out of 900 | elapsed: 273.4min finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100, n_jobs=None,
#                                              oob_score=False, random_state=None,
#                                              verbose=0, warm_start=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'criterion': ['mse'], 'max_features': ['auto'],
#                          'min_samples_leaf': [2, 3, 4, 5, 6, 7],
#                          'min_samples_split': [2, 3, 4, 5, 6, 7],
#                          'n_estimators': [100, 200, 300, 700, 1000]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=4)

# %%
rndfor_select.best_params_
# Out:
# {'criterion': 'mse',
#  'max_features': 'auto',
#  'min_samples_leaf': 2,
#  'min_samples_split': 6,
#  'n_estimators': 700}

# %% [markdown]
# Best model:

# %%
models = {
    
    
    "RandForest" : RandomForestRegressor(n_estimators=rndfor_select.best_params_['n_estimators'], 
                                                     criterion=rndfor_select.best_params_['criterion'],
                                                     max_features=rndfor_select.best_params_['max_features'], 
                                                     max_depth=None, 
                                                     min_samples_split=rndfor_select.best_params_['min_samples_split'], 
                                                     min_samples_leaf=rndfor_select.best_params_['min_samples_leaf'], random_state=0),

}



for modelName, model in models.items():
    print(f"Training model: {modelName}")
    model.fit(X_train, y_train)
print('Training done')
for name, model in models.items():
    print(f"---------[{name}]---------:")
    y_pred = model.predict(X_test)
    #y_pred_backtransformed =np.array([math.exp(e)-1 for e in y_pred])
    print("MSE = ",round(mean_squared_error(y_test,y_pred),5))
    print("RMSE = ",np.sqrt(mean_squared_error(y_test,y_pred)))
    print(r2_score(y_test, y_pred))
# Out:
# Training model: RandForest
# Training done
# ---------[RandForest]---------:
# MSE =  306147.28114
# RMSE =  553.3057754482417
# 0.9807948319134133
